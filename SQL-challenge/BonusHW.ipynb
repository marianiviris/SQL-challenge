# %%
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import uid, pwd, database, server

# %%
engine = create_engine(f"postgres://{uid}:{pwd}@{server}/{database}")
conn = engine.connect()

# %%
salaries = pd.read_sql("SELECT * FROM salaries", conn)
salaries.head()
# Out:
#    emp_no  salary   from_date     to_date
# 0   10001   60117  1986-06-26  1987-06-26
# 1   10002   65828  1996-08-03  1997-08-03
# 2   10003   40006  1995-12-03  1996-12-02
# 3   10004   40054  1986-12-01  1987-12-01
# 4   10005   78228  1989-09-12  1990-09-12

# %%
titles = pd.read_sql("SELECT * FROM titles", conn)
titles.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
merged = pd.merge(salaries, titles, on="emp_no", how="inner")
merged.head()
# Out:
#    emp_no  salary from_date_x   to_date_x            title from_date_y  \
# 0   10001   60117  1986-06-26  1987-06-26  Senior Engineer  1986-06-26
# 1   10002   65828  1996-08-03  1997-08-03            Staff  1996-08-03
# 2   10003   40006  1995-12-03  1996-12-02  Senior Engineer  1995-12-03
# 3   10004   40054  1986-12-01  1987-12-01         Engineer  1986-12-01
# 4   10004   40054  1986-12-01  1987-12-01  Senior Engineer  1995-12-01
#
#     to_date_y
# 0  9999-01-01
# 1  9999-01-01
# 2  9999-01-01
# 3  1995-12-01
# 4  9999-01-01

# %%
grouped = merged.groupby("title").mean()
grouped
# Out:
#                            emp_no        salary
# title
# Assistant Engineer  251495.398533  48493.204786
# Engineer            252943.159987  48539.781423
# Manager             110780.833333  51531.041667
# Senior Engineer     253034.375949  48506.751806
# Senior Staff        253423.367183  58503.286614
# Staff               253399.240672  58465.271904
# Technique Leader    251708.951052  48580.505772

# %%
title_salary_df = grouped.drop(columns = "emp_no")
title_salary_df = title_salary_df.reset_index()
title_salary_df.sort_values("salary",inplace=True)
title_salary_df
# Out:
#                 title        salary
# 0  Assistant Engineer  48493.204786
# 3     Senior Engineer  48506.751806
# 1            Engineer  48539.781423
# 6    Technique Leader  48580.505772
# 2             Manager  51531.041667
# 5               Staff  58465.271904
# 4        Senior Staff  58503.286614

# %%
x_axis = title_salary_df["title"]
ticks = np.arange(len(x_axis))
y_axis = title_salary_df["salary"]
 
plt.bar(x_axis, y_axis, align="center", alpha=1.0, color=["darkblue", "slateblue", "rebeccapurple",\
                                                          "darkviolet", "violet", "fuchsia", "deeppink"])
plt.xticks(ticks, x_axis, rotation="vertical")
plt.ylim(40000, 60000)
plt.ylabel("Salaries ($)")
plt.xlabel("Employee Title")
plt.title("Average Employee Salary by Title")
plt.grid(linestyle='--', dashes=(1, 4), linewidth=0.5, color='black')

plt.savefig("Salary by title.png")
plt.show()

# %% [markdown]
# # Technical Report
#
# ##Perfomed Data Modeling by inspecting the CSV files and creating an Entity Relationship Diagram (ERD) of the tables for the employee database, using a tool called Lucid Chart.
#
# ##Performed Data Engineering by exporting the ERD to PostgreSQL, which created a table schema for each CSV file, showing the specified data types, primary/foreign keys for each respective table. After creating total of 6 tables, each corresponding CSV file was imported and the tables content was evaluated.
#
# ##Performed Data Analysis by querying the Employee Database, based on the questions proposed. Imported the SQL Database into Pandas, by creating an engine. Performed data manipulation and created a bar chart showing average salary per title.
